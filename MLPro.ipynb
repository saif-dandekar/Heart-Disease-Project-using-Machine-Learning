# %%
import numpy as np                   
import pandas as pd                  
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['HeartDisease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
col = ["Age","RestingBP","Cholesterol","MaxHR"]

for c,i in enumerate(col,1):

    plt.subplot(2,2,c)
    sns.histplot(x = df[i])
plt.tight_layout()
plt.show()

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
ch_mean = df.loc[df['Cholesterol'] != 0,"Cholesterol"].mean()

# %%
ch_mean
# Out:
# np.float64(244.6353887399464)

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0,ch_mean)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %%
ch_mean = df.loc[df['RestingBP'] != 0,"RestingBP"].mean()

df['RestingBP'] = df['RestingBP'].replace(0,ch_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %%
col = ["Age","RestingBP","Cholesterol","MaxHR"]

for c,i in enumerate(col,1):

    plt.subplot(2,2,c)
    sns.histplot(x = df[i])
plt.tight_layout()
plt.show()

# %%
sns.countplot(x=df["Sex"],hue=df["HeartDisease"])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x=df["ChestPainType"],hue=df["HeartDisease"])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x=df["FastingBS"],hue=df["HeartDisease"])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.boxplot(x="HeartDisease",y="Cholesterol",data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x="HeartDisease",y="Age",data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df_encode = pd.get_dummies(df,drop_first=True)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40      140.0        289.0          0    172      0.0             0
# 1     49      160.0        180.0          0    156      1.0             1
# 2     37      130.0        283.0          0     98      0.0             0
# 3     48      138.0        214.0          0    108      1.5             1
# 4     54      150.0        195.0          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45      110.0        264.0          0    132      1.2             1
# 914   68      144.0        193.0          1    141      3.4             1
# 915   57      130.0        131.0          0    115      1.2             1
# 916   57      130.0        236.0          0    174      0.0             1
# 917   38      138.0        175.0          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode = df_encode.astype(int)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease', 'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_Y', 'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %%
l_encode = df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode = LabelEncoder()

col = ['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope']

for i in col:
    l_encode[i] =encode.fit_transform(l_encode[i]) 

l_encode
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1      140.0        289.0          0           1
# 1     49    0              2      160.0        180.0          0           1
# 2     37    1              1      130.0        283.0          0           2
# 3     48    0              0      138.0        214.0          0           1
# 4     54    1              2      150.0        195.0          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3      110.0        264.0          0           1
# 914   68    1              0      144.0        193.0          1           1
# 915   57    1              0      130.0        131.0          0           1
# 916   57    0              1      130.0        236.0          0           0
# 917   38    1              2      138.0        175.0          0           1
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,f1_score,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
X = df_encode.drop('HeartDisease',axis =1)
y = df_encode['HeartDisease']

# %%
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0     40        140          289          0    172        0      1
# 1     49        160          180          0    156        1      0
# 2     37        130          283          0     98        0      1
# 3     48        138          214          0    108        1      0
# 4     54        150          195          0    122        0      1
# ..   ...        ...          ...        ...    ...      ...    ...
# 913   45        110          264          0    132        1      1
# 914   68        144          193          1    141        3      1
# 915   57        130          131          0    115        1      1
# 916   57        130          236          0    174        0      0
# 917   38        138          175          0    173        0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %% [markdown]
# We split the data into training and testing sets to check how well the model performs on unseen data.

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# After splitting the dataset into training and testing sets, five classification models—Logistic Regression, K-Nearest Neighbors (KNN), Naive Bayes, Decision Tree, and Support Vector Machine (SVM)—were applied because they represent different learning approaches, allowing a fair and comprehensive comparison to identify the most accurate and reliable model.

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8695652173913043

# %%
f1 = f1_score(y_test,y_pred)
f1
# Out:
# 0.8857142857142857

# %%
model = KNeighborsClassifier()

model.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(X_test_scaled)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8641304347826086

# %%
f1 = f1_score(y_test,y_pred)
f1
# Out:
# 0.8815165876777251

# %%
model = GaussianNB()
model.fit(X_train_scaled,y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test_scaled)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8532608695652174

# %%
f1 = f1_score(y_test,y_pred)
f1
# Out:
# 0.8682926829268293

# %%
model = DecisionTreeClassifier()
model.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test_scaled)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.7717391304347826

# %%
f1 = f1_score(y_test,y_pred)
f1
# Out:
# 0.7941176470588235

# %%
model = SVC()
model.fit(X_train_scaled,y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test_scaled)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 0.8478260869565217

# %%
f1 = f1_score(y_test,y_pred)
f1
# Out:
# 0.8679245283018868

# %% [markdown]
# This code creates a dictionary that stores multiple machine learning classification models with their names, making it easy to train and compare their performance efficiently.

# %%
models = {
    "Logistic Regression" : LogisticRegression(),
    "KNN" : KNeighborsClassifier(),
    "Naive Byeas" : GaussianNB(),
    "Decision tree" :DecisionTreeClassifier(),
    "SVM" : SVC()
}

# %%
result = []

# %% [markdown]
# This loop trains each model, makes predictions on test data, evaluates performance using accuracy and F1-score, and stores the results in a list for comparison.

# %%
for name,model in models.items():
    model.fit(X_train_scaled,y_train)
    y_pred = model.predict(X_test_scaled)
    acc = accuracy_score(y_test,y_pred)
    f1 = f1_score(y_test,y_pred)
    result.append({
        'model' : name,
        'Accuracy': round(acc,4),
        'f1_score':round(f1,4)

    })

# %%
result
# Out:
# [{'model': 'Logistic Regression', 'Accuracy': 0.8696, 'f1_score': 0.8857},
#  {'model': 'KNN', 'Accuracy': 0.8641, 'f1_score': 0.8815},
#  {'model': 'Naive Byeas', 'Accuracy': 0.8533, 'f1_score': 0.8683},
#  {'model': 'Decision tree', 'Accuracy': 0.7609, 'f1_score': 0.7822},
#  {'model': 'SVM', 'Accuracy': 0.8478, 'f1_score': 0.8679}]

# %% [markdown]
# Summary:
# Among all models, Logistic Regression performs best as it achieves the highest accuracy (86.96%) and F1-score (0.8857), indicating a strong balance between precision and recall. KNN is a close second, while Decision Tree shows the weakest performance due to lower accuracy and F1-score.
